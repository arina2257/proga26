# %% [markdown]
# <a href="https://colab.research.google.com/github/arina2257/proga26/blob/main/%D0%BB%D0%B0%D0%B1_1_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# задание task_01_09

# выполнила: Ермакова Арина
# группа: ЦИБ-251
# электронная почта: ermakovaas800@mgpu.ru

word = 'объектно-ориентированный'
print(word[0:6])
print(word[9:17])
print(word[14:17])
print(word[4] + word[7] + word[5])
print(word[10] + word[12] + word[13] + word[14] + word[19])
# Out:
# объект
# ориентир
# тир
# кот
# рента
